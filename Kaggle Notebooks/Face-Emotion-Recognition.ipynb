# %% [markdown]
# # **Project Introduction**
#
#
# The Indian education landscape has been undergoing rapid changes for the past 10 years owing to the advancement of web-based learning services, specifically, eLearning platforms.
#     Global E-learning is estimated to witness an 8X over the next 5 years to reach USD 2B in 2021. India is expected to grow with a CAGR of 44% crossing the 10M users mark in 2021. Although the market is growing on a rapid scale, there are major challenges associated with digital learning when compared with brick and mortar classrooms.
# One of many challenges is how to ensure quality learning for students.
#
#    Digital platforms might overpower physical classrooms in terms of content quality but when it comes to understanding whether students are able to grasp the content in a live class scenario is yet an open-end challenge.
# In a physical classroom during a lecturing teacher can see the faces and assess the emotion of the class and tune their lecture accordingly, whether he is going fast or slow. He can identify students who need special attention.
# Digital classrooms are conducted via video telephony software program (ex-Zoom) where it’s not possible for medium scale class (25-50) to see all students and access the mood. Because of this drawback, students are not focusing on content due to lack of surveillance.
#
#    While digital platforms have limitations in terms of physical surveillance but it comes with the power of data and machines which can work for you. It provides data in the form of video, audio, and texts which can be analyzed using deep learning algorithms.
#     Deep learning backed system not only solves the surveillance issue, but it also removes the human bias from the system, and all information is no longer in the teacher’s brain rather translated in numbers that can be analyzed and tracked.
#     I will solve the above-mentioned challenge by applying deep learning algorithms to live video data.
# The solution to this problem is by recognizing facial emotions.

# %% [markdown]
# # **Importing Important libraries for CNN model**

# %%
#Importing Libraries

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import os

#Deep Learning 
import tensorflow as tf
from keras.preprocessing.image import img_to_array,load_img,ImageDataGenerator
from keras.layers import Dense,Input,Dropout, GlobalAveragePooling2D,Flatten,Conv2D, BatchNormalization,Activation,MaxPooling2D
from keras.models import load_model,Model,Sequential
from keras.optimizers import Adam,SGD, RMSprop
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# %% [markdown]
# # Declaration of Images sizes

# %%
pic_size=48
folder_path='../input/face-expression-recognition-dataset/images/'

# %% [markdown]
# # Display dataset of fear
# * How the data set images looklike
# * How many images of training and testing images are available

# %%
expression='fear'

plt.figure(figsize=(20,20))
for i in range(1,18,1):
    plt.subplot(6,6,i)
    img=load_img(folder_path+'train/'+expression+"/"+
                os.listdir(folder_path + 'train/' + expression)[i],target_size=(pic_size,pic_size))
    plt.imshow(img)
plt.show()

# %% [markdown]
# # Training and validating

# %%
batch_size=128


# Let's use some data augmentaiton
datagen_train= ImageDataGenerator(rescale = 1.0/255.0,
                                  width_shift_range = 0.1,
                                   height_shift_range = 0.1,
                                   rotation_range = 20,
                                   horizontal_flip = True)
datagen_val = ImageDataGenerator(rescale= 1.0/255)

train_set = datagen_train.flow_from_directory(folder_path+'train',target_size=(pic_size,pic_size),color_mode='grayscale',
                                              batch_size=batch_size,
                                              class_mode='categorical',
                                              shuffle=True)

test_set= datagen_val.flow_from_directory(folder_path+'validation',
                                            target_size=(pic_size,pic_size),
                                            color_mode='grayscale',
                                            batch_size=batch_size,
                                            class_mode='categorical',
                                            shuffle=False)
# Out:
# Found 28821 images belonging to 7 classes.
# Found 7066 images belonging to 7 classes.

# %% [markdown]
# # Applied Sequential Model of 4 convolutions and 2 Fully connected layers
# #How many parameters are available at each layers?

# %%
no_of_classes=7
model=Sequential()

#1st CNN Layer
model.add(Conv2D(64,(3,3),padding='same', input_shape=(48,48,1)) )
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

#2nd CNN Layer
model.add(Conv2D(128,(5,5),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(.25))

#3rd CNN Layer
model.add(Conv2D(512,(3,3), padding=('same')))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

#4th CNN Layer
model.add(Conv2D(512,(3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())

#fully connected 1st Layer
model.add(Dense(256))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))

#Fully connected 2nd layer
model.add(Dense(512))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))

model.add(Dense(no_of_classes, activation='softmax'))


opt=Adam(lr=.0001)
model.compile(optimizer=opt,loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 48, 48, 64)        640
# _________________________________________________________________
# batch_normalization (BatchNo (None, 48, 48, 64)        256
# _________________________________________________________________
# activation (Activation)      (None, 48, 48, 64)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 24, 24, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 24, 24, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 24, 24, 128)       204928
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 24, 24, 128)       512
# _________________________________________________________________
# activation_1 (Activation)    (None, 24, 24, 128)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 12, 12, 128)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 12, 12, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 12, 12, 512)       590336
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 12, 12, 512)       2048
# _________________________________________________________________
# activation_2 (Activation)    (None, 12, 12, 512)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 6, 6, 512)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 6, 6, 512)         2359808
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 6, 6, 512)         2048
# _________________________________________________________________
# activation_3 (Activation)    (None, 6, 6, 512)         0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 3, 3, 512)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 3, 3, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 4608)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               1179904
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_4 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               131584
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 512)               2048
# _________________________________________________________________
# activation_5 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 3591
# =================================================================
# Total params: 4,478,727
# Trainable params: 4,474,759
# Non-trainable params: 3,968
# _________________________________________________________________

# %% [markdown]
# # Model Fitting and Check Points to save the model best weights!

# %%
# number of epochs to train the NN
epochs = 150

# checkpoint to save best model
from keras.callbacks import ModelCheckpoint

checkpoint=ModelCheckpoint(filepath='./modelbestweights.h5', mode='max', monitor='val_accuracy', verbose=1, save_best_only=True)



callbacks_list=[checkpoint]


model.compile(loss='categorical_crossentropy',optimizer=Adam(lr=.001),metrics=['accuracy'])

# %%
history=model.fit_generator(train_set,
                           steps_per_epoch=train_set.n//train_set.batch_size,
                           epochs=epochs,
                           validation_data=test_set,
                           validation_steps=test_set.n//test_set.batch_size,
                           callbacks=callbacks_list)
# Out:
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/150
# 225/225 [==============================] - 165s 714ms/step - loss: 1.9830 - accuracy: 0.2215 - val_loss: 1.8756 - val_accuracy: 0.2592
#
# Epoch 00001: val_accuracy improved from -inf to 0.25923, saving model to ./modelbestweights.h5
# Epoch 2/150
# 225/225 [==============================] - 36s 161ms/step - loss: 1.7475 - accuracy: 0.3069 - val_loss: 2.1139 - val_accuracy: 0.2639
#
# Epoch 00002: val_accuracy improved from 0.25923 to 0.26392, saving model to ./modelbestweights.h5
# Epoch 3/150
# 225/225 [==============================] - 37s 165ms/step - loss: 1.5232 - accuracy: 0.4091 - val_loss: 1.3477 - val_accuracy: 0.4659
#
# Epoch 00003: val_accuracy improved from 0.26392 to 0.46591, saving model to ./modelbestweights.h5
# Epoch 4/150
# 225/225 [==============================] - 38s 167ms/step - loss: 1.3833 - accuracy: 0.4675 - val_loss: 1.5364 - val_accuracy: 0.4068
#
# Epoch 00004: val_accuracy did not improve from 0.46591
# Epoch 5/150
# 225/225 [==============================] - 36s 159ms/step - loss: 1.3180 - accuracy: 0.4953 - val_loss: 1.4266 - val_accuracy: 0.4561
#
# Epoch 00005: val_accuracy did not improve from 0.46591
# Epoch 6/150
# 225/225 [==============================] - 38s 167ms/step - loss: 1.2779 - accuracy: 0.5053 - val_loss: 1.3218 - val_accuracy: 0.4999
#
# Epoch 00006: val_accuracy improved from 0.46591 to 0.49986, saving model to ./modelbestweights.h5
# Epoch 7/150
# 225/225 [==============================] - 37s 163ms/step - loss: 1.2211 - accuracy: 0.5333 - val_loss: 1.2683 - val_accuracy: 0.5143
#
# Epoch 00007: val_accuracy improved from 0.49986 to 0.51435, saving model to ./modelbestweights.h5
# Epoch 8/150
# 225/225 [==============================] - 37s 164ms/step - loss: 1.1981 - accuracy: 0.5406 - val_loss: 1.2608 - val_accuracy: 0.5286
#
# Epoch 00008: val_accuracy improved from 0.51435 to 0.52855, saving model to ./modelbestweights.h5
# Epoch 9/150
# 225/225 [==============================] - 37s 163ms/step - loss: 1.1881 - accuracy: 0.5480 - val_loss: 1.2404 - val_accuracy: 0.5321
#
# Epoch 00009: val_accuracy improved from 0.52855 to 0.53210, saving model to ./modelbestweights.h5
# Epoch 10/150
# 225/225 [==============================] - 37s 162ms/step - loss: 1.1593 - accuracy: 0.5542 - val_loss: 1.4377 - val_accuracy: 0.4375
#
# Epoch 00010: val_accuracy did not improve from 0.53210
# Epoch 11/150
# 225/225 [==============================] - 38s 169ms/step - loss: 1.1407 - accuracy: 0.5657 - val_loss: 1.1698 - val_accuracy: 0.5455
#
# Epoch 00011: val_accuracy improved from 0.53210 to 0.54545, saving model to ./modelbestweights.h5
# Epoch 12/150
# 225/225 [==============================] - 38s 168ms/step - loss: 1.1179 - accuracy: 0.5700 - val_loss: 1.1551 - val_accuracy: 0.5624
#
# Epoch 00012: val_accuracy improved from 0.54545 to 0.56236, saving model to ./modelbestweights.h5
# Epoch 13/150
# 225/225 [==============================] - 35s 157ms/step - loss: 1.1118 - accuracy: 0.5777 - val_loss: 1.0268 - val_accuracy: 0.6143
#
# Epoch 00013: val_accuracy improved from 0.56236 to 0.61435, saving model to ./modelbestweights.h5
# Epoch 14/150
# 225/225 [==============================] - 37s 167ms/step - loss: 1.1128 - accuracy: 0.5807 - val_loss: 1.0468 - val_accuracy: 0.6043
#
# Epoch 00014: val_accuracy did not improve from 0.61435
# Epoch 15/150
# 225/225 [==============================] - 37s 163ms/step - loss: 1.0816 - accuracy: 0.5877 - val_loss: 1.0517 - val_accuracy: 0.5942
#
# Epoch 00015: val_accuracy did not improve from 0.61435
# Epoch 16/150
# 225/225 [==============================] - 38s 167ms/step - loss: 1.0720 - accuracy: 0.5884 - val_loss: 1.1212 - val_accuracy: 0.5670
#
# Epoch 00016: val_accuracy did not improve from 0.61435
# Epoch 17/150
# 225/225 [==============================] - 36s 162ms/step - loss: 1.0671 - accuracy: 0.5934 - val_loss: 1.0286 - val_accuracy: 0.6053
#
# Epoch 00017: val_accuracy did not improve from 0.61435
# Epoch 18/150
# 225/225 [==============================] - 37s 164ms/step - loss: 1.0608 - accuracy: 0.6014 - val_loss: 1.0060 - val_accuracy: 0.6226
#
# Epoch 00018: val_accuracy improved from 0.61435 to 0.62259, saving model to ./modelbestweights.h5
# Epoch 19/150
# 225/225 [==============================] - 37s 166ms/step - loss: 1.0476 - accuracy: 0.6008 - val_loss: 1.0589 - val_accuracy: 0.6095
#
# Epoch 00019: val_accuracy did not improve from 0.62259
# Epoch 20/150
# 225/225 [==============================] - 37s 166ms/step - loss: 1.0237 - accuracy: 0.6119 - val_loss: 1.0943 - val_accuracy: 0.5813
#
# Epoch 00020: val_accuracy did not improve from 0.62259
# Epoch 21/150
# 225/225 [==============================] - 38s 171ms/step - loss: 1.0288 - accuracy: 0.6095 - val_loss: 1.0308 - val_accuracy: 0.6099
#
# Epoch 00021: val_accuracy did not improve from 0.62259
# Epoch 22/150
# 225/225 [==============================] - 38s 169ms/step - loss: 1.0088 - accuracy: 0.6219 - val_loss: 1.1608 - val_accuracy: 0.5749
#
# Epoch 00022: val_accuracy did not improve from 0.62259
# Epoch 23/150
# 225/225 [==============================] - 37s 163ms/step - loss: 1.0079 - accuracy: 0.6201 - val_loss: 1.1272 - val_accuracy: 0.5689
#
# Epoch 00023: val_accuracy did not improve from 0.62259
# Epoch 24/150
# 225/225 [==============================] - 39s 173ms/step - loss: 1.0006 - accuracy: 0.6226 - val_loss: 1.1348 - val_accuracy: 0.5605
#
# Epoch 00024: val_accuracy did not improve from 0.62259
# Epoch 25/150
# 225/225 [==============================] - 38s 170ms/step - loss: 0.9915 - accuracy: 0.6252 - val_loss: 1.0518 - val_accuracy: 0.6006
#
# Epoch 00025: val_accuracy did not improve from 0.62259
# Epoch 26/150
# 225/225 [==============================] - 37s 166ms/step - loss: 0.9798 - accuracy: 0.6326 - val_loss: 0.9870 - val_accuracy: 0.6311
#
# Epoch 00026: val_accuracy improved from 0.62259 to 0.63111, saving model to ./modelbestweights.h5
# Epoch 27/150
# 225/225 [==============================] - 38s 169ms/step - loss: 0.9769 - accuracy: 0.6276 - val_loss: 1.0712 - val_accuracy: 0.5994
#
# Epoch 00027: val_accuracy did not improve from 0.63111
# Epoch 28/150
# 225/225 [==============================] - 37s 164ms/step - loss: 0.9520 - accuracy: 0.6366 - val_loss: 1.0327 - val_accuracy: 0.6028
#
# Epoch 00028: val_accuracy did not improve from 0.63111
# Epoch 29/150
# 225/225 [==============================] - 38s 171ms/step - loss: 0.9614 - accuracy: 0.6358 - val_loss: 0.9489 - val_accuracy: 0.6518
#
# Epoch 00029: val_accuracy improved from 0.63111 to 0.65185, saving model to ./modelbestweights.h5
# Epoch 30/150
# 225/225 [==============================] - 38s 171ms/step - loss: 0.9592 - accuracy: 0.6352 - val_loss: 1.0345 - val_accuracy: 0.6027
#
# Epoch 00030: val_accuracy did not improve from 0.65185
# Epoch 31/150
# 225/225 [==============================] - 38s 168ms/step - loss: 0.9376 - accuracy: 0.6434 - val_loss: 1.1377 - val_accuracy: 0.5685
#
# Epoch 00031: val_accuracy did not improve from 0.65185
# Epoch 32/150
# 225/225 [==============================] - 38s 168ms/step - loss: 0.9416 - accuracy: 0.6419 - val_loss: 0.9507 - val_accuracy: 0.6416
#
# Epoch 00032: val_accuracy did not improve from 0.65185
# Epoch 33/150
# 225/225 [==============================] - 39s 171ms/step - loss: 0.9306 - accuracy: 0.6494 - val_loss: 0.9983 - val_accuracy: 0.6273
#
# Epoch 00033: val_accuracy did not improve from 0.65185
# Epoch 34/150
# 225/225 [==============================] - 37s 163ms/step - loss: 0.9156 - accuracy: 0.6565 - val_loss: 1.1218 - val_accuracy: 0.5625
#
# Epoch 00034: val_accuracy did not improve from 0.65185
# Epoch 35/150
# 225/225 [==============================] - 38s 169ms/step - loss: 0.9251 - accuracy: 0.6500 - val_loss: 0.9726 - val_accuracy: 0.6381
#
# Epoch 00035: val_accuracy did not improve from 0.65185
# Epoch 36/150
# 225/225 [==============================] - 36s 161ms/step - loss: 0.9209 - accuracy: 0.6542 - val_loss: 0.9706 - val_accuracy: 0.6416
#
# Epoch 00036: val_accuracy did not improve from 0.65185
# Epoch 37/150
# 225/225 [==============================] - 38s 169ms/step - loss: 0.9097 - accuracy: 0.6563 - val_loss: 0.9745 - val_accuracy: 0.6274
#
# Epoch 00037: val_accuracy did not improve from 0.65185
# Epoch 38/150
# 225/225 [==============================] - 37s 166ms/step - loss: 0.9125 - accuracy: 0.6558 - val_loss: 0.9478 - val_accuracy: 0.6528
#
# Epoch 00038: val_accuracy improved from 0.65185 to 0.65284, saving model to ./modelbestweights.h5
# Epoch 39/150
# 225/225 [==============================] - 38s 167ms/step - loss: 0.8950 - accuracy: 0.6627 - val_loss: 0.9980 - val_accuracy: 0.6303
#
# Epoch 00039: val_accuracy did not improve from 0.65284
# Epoch 40/150
# 225/225 [==============================] - 37s 166ms/step - loss: 0.8854 - accuracy: 0.6696 - val_loss: 0.9794 - val_accuracy: 0.6348
#
# Epoch 00040: val_accuracy did not improve from 0.65284
# Epoch 41/150
# 225/225 [==============================] - 38s 169ms/step - loss: 0.8821 - accuracy: 0.6672 - val_loss: 1.0425 - val_accuracy: 0.6105
#
# Epoch 00041: val_accuracy did not improve from 0.65284
# Epoch 42/150
# 225/225 [==============================] - 36s 159ms/step - loss: 0.8839 - accuracy: 0.6635 - val_loss: 1.1252 - val_accuracy: 0.5795
#
# Epoch 00042: val_accuracy did not improve from 0.65284
# Epoch 43/150
# 225/225 [==============================] - 38s 168ms/step - loss: 0.8730 - accuracy: 0.6723 - val_loss: 1.1027 - val_accuracy: 0.5886
#
# Epoch 00043: val_accuracy did not improve from 0.65284
# Epoch 44/150
# 225/225 [==============================] - 37s 163ms/step - loss: 0.8632 - accuracy: 0.6774 - val_loss: 1.0340 - val_accuracy: 0.6143
#
# Epoch 00044: val_accuracy did not improve from 0.65284
# Epoch 45/150
# 225/225 [==============================] - 37s 166ms/step - loss: 0.8685 - accuracy: 0.6793 - val_loss: 1.0305 - val_accuracy: 0.6165
#
# Epoch 00045: val_accuracy did not improve from 0.65284
# Epoch 46/150
# 225/225 [==============================] - 37s 165ms/step - loss: 0.8419 - accuracy: 0.6887 - val_loss: 1.1463 - val_accuracy: 0.5811
#
# Epoch 00046: val_accuracy did not improve from 0.65284
# Epoch 47/150
# 225/225 [==============================] - 38s 169ms/step - loss: 0.8547 - accuracy: 0.6778 - val_loss: 1.0193 - val_accuracy: 0.6230
#
# Epoch 00047: val_accuracy did not improve from 0.65284
# Epoch 48/150
# 225/225 [==============================] - 37s 164ms/step - loss: 0.8542 - accuracy: 0.6790 - val_loss: 1.0132 - val_accuracy: 0.6226
#
# Epoch 00048: val_accuracy did not improve from 0.65284
# Epoch 49/150
# 225/225 [==============================] - 38s 169ms/step - loss: 0.8395 - accuracy: 0.6874 - val_loss: 1.3705 - val_accuracy: 0.4984
#
# Epoch 00049: val_accuracy did not improve from 0.65284
# Epoch 50/150
# 225/225 [==============================] - 36s 159ms/step - loss: 0.8310 - accuracy: 0.6850 - val_loss: 0.9934 - val_accuracy: 0.6335
#
# Epoch 00050: val_accuracy did not improve from 0.65284
# Epoch 51/150
# 225/225 [==============================] - 38s 168ms/step - loss: 0.8243 - accuracy: 0.6943 - val_loss: 1.0726 - val_accuracy: 0.5997
#
# Epoch 00051: val_accuracy did not improve from 0.65284
# Epoch 52/150
# 225/225 [==============================] - 37s 162ms/step - loss: 0.8183 - accuracy: 0.6890 - val_loss: 0.9341 - val_accuracy: 0.6571
#
# Epoch 00052: val_accuracy improved from 0.65284 to 0.65710, saving model to ./modelbestweights.h5
# Epoch 53/150
# 225/225 [==============================] - 37s 165ms/step - loss: 0.8191 - accuracy: 0.6918 - val_loss: 1.1198 - val_accuracy: 0.5820
#
# Epoch 00053: val_accuracy did not improve from 0.65710
# Epoch 54/150
# 225/225 [==============================] - 37s 164ms/step - loss: 0.8086 - accuracy: 0.6958 - val_loss: 1.0709 - val_accuracy: 0.5986
#
# Epoch 00054: val_accuracy did not improve from 0.65710
# Epoch 55/150
# 225/225 [==============================] - 38s 169ms/step - loss: 0.8114 - accuracy: 0.6942 - val_loss: 0.9878 - val_accuracy: 0.6388
#
# Epoch 00055: val_accuracy did not improve from 0.65710
# Epoch 56/150
# 225/225 [==============================] - 37s 164ms/step - loss: 0.8101 - accuracy: 0.6942 - val_loss: 0.9875 - val_accuracy: 0.6403
#
# Epoch 00056: val_accuracy did not improve from 0.65710
# Epoch 57/150
# 225/225 [==============================] - 40s 176ms/step - loss: 0.8033 - accuracy: 0.6980 - val_loss: 0.9265 - val_accuracy: 0.6568
#
# Epoch 00057: val_accuracy did not improve from 0.65710
# Epoch 58/150
# 225/225 [==============================] - 36s 161ms/step - loss: 0.7969 - accuracy: 0.7005 - val_loss: 0.9485 - val_accuracy: 0.6501
#
# Epoch 00058: val_accuracy did not improve from 0.65710
# Epoch 59/150
# 225/225 [==============================] - 38s 168ms/step - loss: 0.7894 - accuracy: 0.7042 - val_loss: 0.9370 - val_accuracy: 0.6587
#
# Epoch 00059: val_accuracy improved from 0.65710 to 0.65866, saving model to ./modelbestweights.h5
# Epoch 60/150
# 225/225 [==============================] - 37s 163ms/step - loss: 0.7777 - accuracy: 0.7074 - val_loss: 1.0764 - val_accuracy: 0.6095
#
# Epoch 00060: val_accuracy did not improve from 0.65866
# Epoch 61/150
# 225/225 [==============================] - 38s 168ms/step - loss: 0.7765 - accuracy: 0.7081 - val_loss: 1.0777 - val_accuracy: 0.6101
#
# Epoch 00061: val_accuracy did not improve from 0.65866
# Epoch 62/150
# 225/225 [==============================] - 38s 167ms/step - loss: 0.7668 - accuracy: 0.7108 - val_loss: 1.0483 - val_accuracy: 0.6161
#
# Epoch 00062: val_accuracy did not improve from 0.65866
# Epoch 63/150
# 225/225 [==============================] - 37s 166ms/step - loss: 0.7787 - accuracy: 0.7074 - val_loss: 0.9774 - val_accuracy: 0.6462
#
# Epoch 00063: val_accuracy did not improve from 0.65866
# Epoch 64/150
# 225/225 [==============================] - 38s 169ms/step - loss: 0.7662 - accuracy: 0.7133 - val_loss: 0.9918 - val_accuracy: 0.6341
#
# Epoch 00064: val_accuracy did not improve from 0.65866
# Epoch 65/150
# 225/225 [==============================] - 39s 173ms/step - loss: 0.7541 - accuracy: 0.7158 - val_loss: 1.0787 - val_accuracy: 0.6011
#
# Epoch 00065: val_accuracy did not improve from 0.65866
# Epoch 66/150
# 225/225 [==============================] - 37s 163ms/step - loss: 0.7549 - accuracy: 0.7157 - val_loss: 0.9550 - val_accuracy: 0.6595
#
# Epoch 00066: val_accuracy improved from 0.65866 to 0.65952, saving model to ./modelbestweights.h5
# Epoch 67/150
# 225/225 [==============================] - 38s 169ms/step - loss: 0.7517 - accuracy: 0.7183 - val_loss: 1.0891 - val_accuracy: 0.6082
#
# Epoch 00067: val_accuracy did not improve from 0.65952
# Epoch 68/150
# 225/225 [==============================] - 37s 165ms/step - loss: 0.7459 - accuracy: 0.7178 - val_loss: 1.0988 - val_accuracy: 0.6124
#
# Epoch 00068: val_accuracy did not improve from 0.65952
# Epoch 69/150
# 225/225 [==============================] - 37s 165ms/step - loss: 0.7563 - accuracy: 0.7156 - val_loss: 1.0822 - val_accuracy: 0.6055
#
# Epoch 00069: val_accuracy did not improve from 0.65952
# Epoch 70/150
# 225/225 [==============================] - 38s 168ms/step - loss: 0.7380 - accuracy: 0.7240 - val_loss: 0.9860 - val_accuracy: 0.6516
#
# Epoch 00070: val_accuracy did not improve from 0.65952
# Epoch 71/150
# 225/225 [==============================] - 37s 162ms/step - loss: 0.7470 - accuracy: 0.7187 - val_loss: 1.5823 - val_accuracy: 0.4682
#
# Epoch 00071: val_accuracy did not improve from 0.65952
# Epoch 72/150
# 225/225 [==============================] - 38s 170ms/step - loss: 0.7371 - accuracy: 0.7197 - val_loss: 0.9475 - val_accuracy: 0.6645
#
# Epoch 00072: val_accuracy improved from 0.65952 to 0.66449, saving model to ./modelbestweights.h5
# Epoch 73/150
# 225/225 [==============================] - 39s 172ms/step - loss: 0.7397 - accuracy: 0.7210 - val_loss: 1.0020 - val_accuracy: 0.6413
#
# Epoch 00073: val_accuracy did not improve from 0.66449
# Epoch 74/150
# 225/225 [==============================] - 37s 165ms/step - loss: 0.7344 - accuracy: 0.7256 - val_loss: 1.0042 - val_accuracy: 0.6396
#
# Epoch 00074: val_accuracy did not improve from 0.66449
# Epoch 75/150
# 225/225 [==============================] - 38s 167ms/step - loss: 0.7299 - accuracy: 0.7277 - val_loss: 1.0344 - val_accuracy: 0.6352
#
# Epoch 00075: val_accuracy did not improve from 0.66449
# Epoch 76/150
# 225/225 [==============================] - 37s 164ms/step - loss: 0.7246 - accuracy: 0.7267 - val_loss: 0.9371 - val_accuracy: 0.6741
#
# Epoch 00076: val_accuracy improved from 0.66449 to 0.67415, saving model to ./modelbestweights.h5
# Epoch 77/150
# 225/225 [==============================] - 37s 163ms/step - loss: 0.7053 - accuracy: 0.7369 - val_loss: 0.9624 - val_accuracy: 0.6616
#
# Epoch 00077: val_accuracy did not improve from 0.67415
# Epoch 78/150
# 225/225 [==============================] - 38s 167ms/step - loss: 0.7159 - accuracy: 0.7316 - val_loss: 0.9870 - val_accuracy: 0.6510
#
# Epoch 00078: val_accuracy did not improve from 0.67415
# Epoch 79/150
# 225/225 [==============================] - 36s 160ms/step - loss: 0.7064 - accuracy: 0.7338 - val_loss: 0.9739 - val_accuracy: 0.6558
#
# Epoch 00079: val_accuracy did not improve from 0.67415
# Epoch 80/150
# 225/225 [==============================] - 38s 170ms/step - loss: 0.7116 - accuracy: 0.7322 - val_loss: 1.1324 - val_accuracy: 0.6018
#
# Epoch 00080: val_accuracy did not improve from 0.67415
# Epoch 81/150
# 225/225 [==============================] - 37s 164ms/step - loss: 0.7136 - accuracy: 0.7298 - val_loss: 1.0276 - val_accuracy: 0.6474
#
# Epoch 00081: val_accuracy did not improve from 0.67415
# Epoch 82/150
# 225/225 [==============================] - 39s 173ms/step - loss: 0.7076 - accuracy: 0.7304 - val_loss: 1.0566 - val_accuracy: 0.6212
#
# Epoch 00082: val_accuracy did not improve from 0.67415
# Epoch 83/150
# 225/225 [==============================] - 38s 170ms/step - loss: 0.7064 - accuracy: 0.7332 - val_loss: 0.9758 - val_accuracy: 0.6680
#
# Epoch 00083: val_accuracy did not improve from 0.67415
# Epoch 84/150
# 225/225 [==============================] - 38s 169ms/step - loss: 0.7011 - accuracy: 0.7362 - val_loss: 1.1691 - val_accuracy: 0.6077
#
# Epoch 00084: val_accuracy did not improve from 0.67415
# Epoch 85/150
# 225/225 [==============================] - 37s 165ms/step - loss: 0.6983 - accuracy: 0.7408 - val_loss: 1.0864 - val_accuracy: 0.6226
#
# Epoch 00085: val_accuracy did not improve from 0.67415
# Epoch 86/150
# 225/225 [==============================] - 38s 170ms/step - loss: 0.6774 - accuracy: 0.7464 - val_loss: 1.0210 - val_accuracy: 0.6413
#
# Epoch 00086: val_accuracy did not improve from 0.67415
# Epoch 87/150
# 225/225 [==============================] - 36s 161ms/step - loss: 0.6798 - accuracy: 0.7461 - val_loss: 1.0910 - val_accuracy: 0.6179
#
# Epoch 00087: val_accuracy did not improve from 0.67415
# Epoch 88/150
# 225/225 [==============================] - 38s 169ms/step - loss: 0.6891 - accuracy: 0.7426 - val_loss: 1.1457 - val_accuracy: 0.6047
#
# Epoch 00088: val_accuracy did not improve from 0.67415
# Epoch 89/150
# 225/225 [==============================] - 37s 164ms/step - loss: 0.6768 - accuracy: 0.7459 - val_loss: 1.1468 - val_accuracy: 0.6064
#
# Epoch 00089: val_accuracy did not improve from 0.67415
# Epoch 90/150
# 225/225 [==============================] - 39s 173ms/step - loss: 0.6780 - accuracy: 0.7435 - val_loss: 0.9772 - val_accuracy: 0.6658
#
# Epoch 00090: val_accuracy did not improve from 0.67415
# Epoch 91/150
# 225/225 [==============================] - 37s 165ms/step - loss: 0.6753 - accuracy: 0.7443 - val_loss: 1.1246 - val_accuracy: 0.6095
#
# Epoch 00091: val_accuracy did not improve from 0.67415
# Epoch 92/150
# 225/225 [==============================] - 37s 167ms/step - loss: 0.6827 - accuracy: 0.7456 - val_loss: 1.1235 - val_accuracy: 0.6129
#
# Epoch 00092: val_accuracy did not improve from 0.67415
# Epoch 93/150
# 225/225 [==============================] - 36s 160ms/step - loss: 0.6689 - accuracy: 0.7456 - val_loss: 1.0784 - val_accuracy: 0.6293
#
# Epoch 00093: val_accuracy did not improve from 0.67415
# Epoch 94/150
# 225/225 [==============================] - 38s 168ms/step - loss: 0.6774 - accuracy: 0.7463 - val_loss: 1.1865 - val_accuracy: 0.5918
#
# Epoch 00094: val_accuracy did not improve from 0.67415
# Epoch 95/150
# 225/225 [==============================] - 36s 160ms/step - loss: 0.6613 - accuracy: 0.7502 - val_loss: 1.0929 - val_accuracy: 0.6276
#
# Epoch 00095: val_accuracy did not improve from 0.67415
# Epoch 96/150
# 225/225 [==============================] - 38s 168ms/step - loss: 0.6524 - accuracy: 0.7547 - val_loss: 1.2366 - val_accuracy: 0.5844
#
# Epoch 00096: val_accuracy did not improve from 0.67415
# Epoch 97/150
# 225/225 [==============================] - 37s 163ms/step - loss: 0.6523 - accuracy: 0.7548 - val_loss: 1.0196 - val_accuracy: 0.6544
#
# Epoch 00097: val_accuracy did not improve from 0.67415
# Epoch 98/150
# 225/225 [==============================] - 38s 170ms/step - loss: 0.6573 - accuracy: 0.7576 - val_loss: 0.9754 - val_accuracy: 0.6696
#
# Epoch 00098: val_accuracy did not improve from 0.67415
# Epoch 99/150
# 225/225 [==============================] - 38s 169ms/step - loss: 0.6517 - accuracy: 0.7577 - val_loss: 1.0046 - val_accuracy: 0.6695
#
# Epoch 00099: val_accuracy did not improve from 0.67415
# Epoch 100/150
# 225/225 [==============================] - 38s 171ms/step - loss: 0.6528 - accuracy: 0.7523 - val_loss: 1.0523 - val_accuracy: 0.6420
#
# Epoch 00100: val_accuracy did not improve from 0.67415
# Epoch 101/150
# 225/225 [==============================] - 36s 160ms/step - loss: 0.6483 - accuracy: 0.7584 - val_loss: 1.1017 - val_accuracy: 0.6193
#
# Epoch 00101: val_accuracy did not improve from 0.67415
# Epoch 102/150
# 225/225 [==============================] - 37s 165ms/step - loss: 0.6433 - accuracy: 0.7616 - val_loss: 1.0131 - val_accuracy: 0.6616
#
# Epoch 00102: val_accuracy did not improve from 0.67415
# Epoch 103/150
# 225/225 [==============================] - 35s 157ms/step - loss: 0.6434 - accuracy: 0.7558 - val_loss: 0.9496 - val_accuracy: 0.6805
#
# Epoch 00103: val_accuracy improved from 0.67415 to 0.68054, saving model to ./modelbestweights.h5
# Epoch 104/150
# 225/225 [==============================] - 38s 167ms/step - loss: 0.6354 - accuracy: 0.7627 - val_loss: 1.0504 - val_accuracy: 0.6408
#
# Epoch 00104: val_accuracy did not improve from 0.68054
# Epoch 105/150
# 225/225 [==============================] - 36s 161ms/step - loss: 0.6301 - accuracy: 0.7663 - val_loss: 1.1085 - val_accuracy: 0.6288
#
# Epoch 00105: val_accuracy did not improve from 0.68054
# Epoch 106/150
# 225/225 [==============================] - 37s 165ms/step - loss: 0.6301 - accuracy: 0.7651 - val_loss: 1.2086 - val_accuracy: 0.5969
#
# Epoch 00106: val_accuracy did not improve from 0.68054
# Epoch 107/150
# 225/225 [==============================] - 38s 167ms/step - loss: 0.6229 - accuracy: 0.7666 - val_loss: 1.1697 - val_accuracy: 0.6054
#
# Epoch 00107: val_accuracy did not improve from 0.68054
# Epoch 108/150
# 225/225 [==============================] - 38s 168ms/step - loss: 0.6220 - accuracy: 0.7670 - val_loss: 0.9718 - val_accuracy: 0.6736
#
# Epoch 00108: val_accuracy did not improve from 0.68054
# Epoch 109/150
# 225/225 [==============================] - 36s 158ms/step - loss: 0.6263 - accuracy: 0.7677 - val_loss: 1.2010 - val_accuracy: 0.5913
#
# Epoch 00109: val_accuracy did not improve from 0.68054
# Epoch 110/150
# 225/225 [==============================] - 38s 167ms/step - loss: 0.6355 - accuracy: 0.7595 - val_loss: 1.0613 - val_accuracy: 0.6473
#
# Epoch 00110: val_accuracy did not improve from 0.68054
# Epoch 111/150
# 225/225 [==============================] - 36s 158ms/step - loss: 0.6187 - accuracy: 0.7688 - val_loss: 1.2359 - val_accuracy: 0.5991
#
# Epoch 00111: val_accuracy did not improve from 0.68054
# Epoch 112/150
# 225/225 [==============================] - 37s 165ms/step - loss: 0.6128 - accuracy: 0.7711 - val_loss: 0.9590 - val_accuracy: 0.6759
#
# Epoch 00112: val_accuracy did not improve from 0.68054
# Epoch 113/150
# 225/225 [==============================] - 37s 162ms/step - loss: 0.6143 - accuracy: 0.7694 - val_loss: 1.4264 - val_accuracy: 0.5459
#
# Epoch 00113: val_accuracy did not improve from 0.68054
# Epoch 114/150
# 225/225 [==============================] - 37s 164ms/step - loss: 0.6279 - accuracy: 0.7652 - val_loss: 1.0659 - val_accuracy: 0.6472
#
# Epoch 00114: val_accuracy did not improve from 0.68054
# Epoch 115/150
# 225/225 [==============================] - 37s 163ms/step - loss: 0.6094 - accuracy: 0.7678 - val_loss: 1.0079 - val_accuracy: 0.6703
#
# Epoch 00115: val_accuracy did not improve from 0.68054
# Epoch 116/150
# 225/225 [==============================] - 37s 166ms/step - loss: 0.6116 - accuracy: 0.7700 - val_loss: 1.0970 - val_accuracy: 0.6311
#
# Epoch 00116: val_accuracy did not improve from 0.68054
# Epoch 117/150
# 225/225 [==============================] - 36s 161ms/step - loss: 0.6163 - accuracy: 0.7688 - val_loss: 0.9698 - val_accuracy: 0.6766
#
# Epoch 00117: val_accuracy did not improve from 0.68054
# Epoch 118/150
# 225/225 [==============================] - 37s 166ms/step - loss: 0.6026 - accuracy: 0.7736 - val_loss: 1.4488 - val_accuracy: 0.5437
#
# Epoch 00118: val_accuracy did not improve from 0.68054
# Epoch 119/150
# 225/225 [==============================] - 35s 157ms/step - loss: 0.6107 - accuracy: 0.7734 - val_loss: 0.9733 - val_accuracy: 0.6794
#
# Epoch 00119: val_accuracy did not improve from 0.68054
# Epoch 120/150
# 225/225 [==============================] - 38s 168ms/step - loss: 0.5992 - accuracy: 0.7766 - val_loss: 1.1249 - val_accuracy: 0.6331
#
# Epoch 00120: val_accuracy did not improve from 0.68054
# Epoch 121/150
# 225/225 [==============================] - 35s 158ms/step - loss: 0.6034 - accuracy: 0.7756 - val_loss: 1.0641 - val_accuracy: 0.6500
#
# Epoch 00121: val_accuracy did not improve from 0.68054
# Epoch 122/150
# 225/225 [==============================] - 37s 165ms/step - loss: 0.5918 - accuracy: 0.7778 - val_loss: 1.0779 - val_accuracy: 0.6470
#
# Epoch 00122: val_accuracy did not improve from 0.68054
# Epoch 123/150
# 225/225 [==============================] - 37s 163ms/step - loss: 0.5998 - accuracy: 0.7730 - val_loss: 0.9966 - val_accuracy: 0.6743
#
# Epoch 00123: val_accuracy did not improve from 0.68054
# Epoch 124/150
# 225/225 [==============================] - 37s 165ms/step - loss: 0.5861 - accuracy: 0.7812 - val_loss: 1.0439 - val_accuracy: 0.6562
#
# Epoch 00124: val_accuracy did not improve from 0.68054
# Epoch 125/150
# 225/225 [==============================] - 37s 163ms/step - loss: 0.5859 - accuracy: 0.7797 - val_loss: 1.0755 - val_accuracy: 0.6464
#
# Epoch 00125: val_accuracy did not improve from 0.68054
# Epoch 126/150
# 225/225 [==============================] - 38s 168ms/step - loss: 0.6039 - accuracy: 0.7718 - val_loss: 1.2336 - val_accuracy: 0.6051
#
# Epoch 00126: val_accuracy did not improve from 0.68054
# Epoch 127/150
# 225/225 [==============================] - 35s 156ms/step - loss: 0.5938 - accuracy: 0.7790 - val_loss: 0.9615 - val_accuracy: 0.6751
#
# Epoch 00127: val_accuracy did not improve from 0.68054
# Epoch 128/150
# 225/225 [==============================] - 37s 166ms/step - loss: 0.5831 - accuracy: 0.7815 - val_loss: 1.0254 - val_accuracy: 0.6770
#
# Epoch 00128: val_accuracy did not improve from 0.68054
# Epoch 129/150
# 225/225 [==============================] - 35s 158ms/step - loss: 0.5885 - accuracy: 0.7785 - val_loss: 1.1120 - val_accuracy: 0.6392
#
# Epoch 00129: val_accuracy did not improve from 0.68054
# Epoch 130/150
# 225/225 [==============================] - 37s 166ms/step - loss: 0.5891 - accuracy: 0.7803 - val_loss: 1.1165 - val_accuracy: 0.6355
#
# Epoch 00130: val_accuracy did not improve from 0.68054
# Epoch 131/150
# 225/225 [==============================] - 36s 159ms/step - loss: 0.5750 - accuracy: 0.7853 - val_loss: 1.1548 - val_accuracy: 0.6290
#
# Epoch 00131: val_accuracy did not improve from 0.68054
# Epoch 132/150
# 225/225 [==============================] - 37s 165ms/step - loss: 0.5746 - accuracy: 0.7847 - val_loss: 1.0642 - val_accuracy: 0.6496
#
# Epoch 00132: val_accuracy did not improve from 0.68054
# Epoch 133/150
# 225/225 [==============================] - 36s 160ms/step - loss: 0.5749 - accuracy: 0.7848 - val_loss: 1.0407 - val_accuracy: 0.6700
#
# Epoch 00133: val_accuracy did not improve from 0.68054
# Epoch 134/150
# 225/225 [==============================] - 37s 166ms/step - loss: 0.5702 - accuracy: 0.7857 - val_loss: 1.2033 - val_accuracy: 0.6159
#
# Epoch 00134: val_accuracy did not improve from 0.68054
# Epoch 135/150
# 225/225 [==============================] - 36s 159ms/step - loss: 0.5798 - accuracy: 0.7778 - val_loss: 0.9926 - val_accuracy: 0.6798
#
# Epoch 00135: val_accuracy did not improve from 0.68054
# Epoch 136/150
# 225/225 [==============================] - 37s 166ms/step - loss: 0.5675 - accuracy: 0.7869 - val_loss: 1.1756 - val_accuracy: 0.6375
#
# Epoch 00136: val_accuracy did not improve from 0.68054
# Epoch 137/150
# 225/225 [==============================] - 35s 157ms/step - loss: 0.5662 - accuracy: 0.7876 - val_loss: 1.0366 - val_accuracy: 0.6702
#
# Epoch 00137: val_accuracy did not improve from 0.68054
# Epoch 138/150
# 225/225 [==============================] - 37s 165ms/step - loss: 0.5645 - accuracy: 0.7881 - val_loss: 0.9562 - val_accuracy: 0.6943
#
# Epoch 00138: val_accuracy improved from 0.68054 to 0.69432, saving model to ./modelbestweights.h5
# Epoch 139/150
# 225/225 [==============================] - 35s 156ms/step - loss: 0.5670 - accuracy: 0.7897 - val_loss: 1.0225 - val_accuracy: 0.6744
#
# Epoch 00139: val_accuracy did not improve from 0.69432
# Epoch 140/150
# 225/225 [==============================] - 38s 168ms/step - loss: 0.5687 - accuracy: 0.7913 - val_loss: 1.0069 - val_accuracy: 0.6858
#
# Epoch 00140: val_accuracy did not improve from 0.69432
# Epoch 141/150
# 225/225 [==============================] - 36s 159ms/step - loss: 0.5676 - accuracy: 0.7897 - val_loss: 1.7205 - val_accuracy: 0.5038
#
# Epoch 00141: val_accuracy did not improve from 0.69432
# Epoch 142/150
# 225/225 [==============================] - 37s 164ms/step - loss: 0.5680 - accuracy: 0.7865 - val_loss: 1.2124 - val_accuracy: 0.6317
#
# Epoch 00142: val_accuracy did not improve from 0.69432
# Epoch 143/150
# 225/225 [==============================] - 36s 162ms/step - loss: 0.5630 - accuracy: 0.7875 - val_loss: 1.3422 - val_accuracy: 0.6007
#
# Epoch 00143: val_accuracy did not improve from 0.69432
# Epoch 144/150
# 225/225 [==============================] - 37s 166ms/step - loss: 0.5601 - accuracy: 0.7916 - val_loss: 1.2631 - val_accuracy: 0.6118
#
# Epoch 00144: val_accuracy did not improve from 0.69432
# Epoch 145/150
# 225/225 [==============================] - 36s 160ms/step - loss: 0.5548 - accuracy: 0.7878 - val_loss: 0.9648 - val_accuracy: 0.6940
#
# Epoch 00145: val_accuracy did not improve from 0.69432
# Epoch 146/150
# 225/225 [==============================] - 38s 168ms/step - loss: 0.5440 - accuracy: 0.7971 - val_loss: 1.2137 - val_accuracy: 0.6263
#
# Epoch 00146: val_accuracy did not improve from 0.69432
# Epoch 147/150
# 225/225 [==============================] - 35s 156ms/step - loss: 0.5574 - accuracy: 0.7892 - val_loss: 1.0980 - val_accuracy: 0.6486
#
# Epoch 00147: val_accuracy did not improve from 0.69432
# Epoch 148/150
# 225/225 [==============================] - 37s 164ms/step - loss: 0.5509 - accuracy: 0.7929 - val_loss: 1.0268 - val_accuracy: 0.6795
#
# Epoch 00148: val_accuracy did not improve from 0.69432
# Epoch 149/150
# 225/225 [==============================] - 36s 158ms/step - loss: 0.5488 - accuracy: 0.7957 - val_loss: 1.2224 - val_accuracy: 0.6162
#
# Epoch 00149: val_accuracy did not improve from 0.69432
# Epoch 150/150
# 225/225 [==============================] - 37s 164ms/step - loss: 0.5471 - accuracy: 0.7949 - val_loss: 1.3038 - val_accuracy: 0.5946
#
# Epoch 00150: val_accuracy did not improve from 0.69432

# %% [markdown]
# # Plot accuracy
# Plotting the accuracy and loss fucntion beside

# %%
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
plt.suptitle('Optimizer=Adam', fontsize=17)
plt.ylabel('Loss',fontsize=16)
plt.plot(history.history['loss'],label='Training loss')
plt.plot(history.history['val_loss'],label='Validation Loss')
plt.legend(loc='upper right')

plt.subplot(1,2,2)
plt.ylabel('Accuracy', fontsize=17)
plt.plot(history.history['accuracy'],label='Training Accuracy')
plt.plot(history.history['val_accuracy'],label='Validation Accuracy')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# # **Summary**
# * We used CNN sequential model with 4 Convolution Layers  with relu as activation function and 2 Fully connected layers passed through softmax function
# * We initially got a validation accuracy around 64% with batch size 64, and epochs 50.
# * By Hyper tunning the model to 128 batch size, Epochs =150 with Adaptive learning rate = 0.0001 reach validation accuracy of 69% at 138 Epoch.
# * model which is saved by best weights and highest accuracy is used for deployment.
